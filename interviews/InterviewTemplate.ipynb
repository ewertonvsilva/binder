# %% [markdown]
# # 📘 Interview Notebook
# ### **Kingfisher – Nucleus Data Platform**
#
# Welcome to this technical interview notebook prepared for the **Kingfisher Nucleus Data Platform**.
#
# ## 🚀 Let's begin
#
# The interviewer will  any relevant code to you on this notebook and will explain the steps you need to perform.
